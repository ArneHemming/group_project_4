# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv("df1_Ausbl.csv")
df3=pd.read_csv("df3_Schulab.csv")
df8i=pd.read_csv("df8i_Mig.csv")
df8m=pd.read_csv("df8m_Mig.csv")
df8w=pd.read_csv("df8w_Mig.csv")
df9i=pd.read_csv("df9i_Mig.csv")
df9m=pd.read_csv("df9m_Mig.csv")
df9w=pd.read_csv("df9w_Mig.csv")
dfH=pd.read_csv("dfH_Habl.csv")

# %%
def filter_2D(column_name, key, table): 
    return table[table[column_name].str.contains(key)]

# %%
# Für df1 mit Nationalität und Geschlecht
def plot_func1(column_name, key, table):
    df = filter_2D(column_name, key, table)
    
    ausbe = df["Ausbildungsbereich"].unique()
    fig, ax = plt.subplots()
    for ausb in ausbe:
        ausb_df = df[df["Ausbildungsbereich"] == ausb]
        ax.barh(ausb, ausb_df["percentage"])
    ax.set_xlabel("percentage per distribution")
    ax.set_title(key)
    ax.set_yticklabels(ausbe)
    plt.show

#Für df3 mit Schulabschluss als subplot männlich und weiblich
def plot_func3_2(column_name, key, table):
    df = filter_2D(column_name, key, table)
    
    ausbe = df["Schulart"].unique()
    fig, ax = plt.subplots(2,1, sharex=True)
    for ausb in ausbe:
        ausb_df = df[df["Schulart"] == ausb]
        ax[0].bar(ausb, ausb_df["männlich percentage"])
        ax[1].bar(ausb, ausb_df["weiblich percentage"])
    
    ax[0].set_ylabel("männlich %")
    ax[1].set_ylabel("weiblich %")
    plt.xticks(ausbe, rotation=90)
    plt.show

#Für df3 mit Schulabschluss und männlich oder weiblich als key_value
def plot_func3(column_name_Schulab, key, table, key_value):
    df = filter_2D(column_name_Schulab, key, table)
    
    ausbe = df["Schulart"].unique()
    fig, ax = plt.subplots()
    for ausb in ausbe:
        ausb_df = df[df["Schulart"] == ausb]
        # key_value:"männlich percentage" oder "weiblich percentage"
        ax.barh(ausb, ausb_df[key_value])
    ax.set_title(key_value)
    ax.set_xlabel("percentage")
    ax.set_yticklabels(ausbe)
    
    plt.show

# Für dfH mit Nationalität und Geschlecht
def plot_funcH(column_name_Geschlecht, key, table):
    df = filter_2D(column_name_Geschlecht, key, table)
    
    ausbe = df["Fächergruppe"].unique()
    fig, ax = plt.subplots()
    for ausb in ausbe:
        ausb_df = df[df["Fächergruppe"] == ausb]
        ax.barh(ausb, ausb_df["percentage"])
    ax.set_xlabel("percentage per distribution")
    ax.set_title(key)
    ax.set_yticklabels(ausbe)
    plt.show


# Für df8,df9 mit {i,m,w}                
def plot_func_all(table):
    table.plot(x="Detaillierter Migrationshintergrund", y=['Prozentual (ohne Migrationshintergrund)', 'Prozentual (mit Migrationshintergrund)'], kind="bar",figsize=(9,8))
    plt.show()

# nicht sehr schön ausarbeitet
def plot_func_select(column_name, key, table):
    df= filter_2D(column_name, key, table)
    df.plot(x="Detaillierter Migrationshintergrund", y=['Prozentual (ohne Migrationshintergrund)', 'Prozentual (mit Migrationshintergrund)'], kind="bar",title=key, figsize=(9,8))
    plt.show()

# %%
#Ask user for their name
print("""
Wie lautet dein Name?
""")

name = input("Bitte gib deinen Namen an: ") 

name = name.title()
print("""
Hey {}, willkommen zu unserem Fragebogen. Dir werden im
Folgenden insgesamt fünf Fragen gestellt anhand derer wir dir gerne
ein paar Graphiken zur Bildungs- und (damit einhergehend) Chancenungleichheit
in Deutschland aufzeigen wollen.
Bitte beantworte die Fragen mit der davorstehenden Nummer
""".format(name))

#Question1
print("""
Dein Geschlecht?

1. männlich 
2. weiblich 

""")

response1 = input("Deine Antwort ist Nummer:")



#Question2
print("""
Hast du einen Migrationshintergrund im weiteren Sinne (das schließt auch Eltern oder Großeltern mit ein)?

1. Ja 
2. Nein 

""")

response2 = input("Deine Antwort ist Nummer:")



#Question3
print("""
Welchen Schulabschluss strebst du an (falls du noch in der Schule bist)?

1. Hauptschulabschluss 
2. Realschulabschluss 
3. Fachhochschulreife 
4. Abitur
5. nicht mehr in der Schule/keinen

""")

response3 = input("Deine Antwort ist Nummer:")



#Question4
print("""
Welchen berufsqualifizierenden Abschluss strebst du an (wenn du noch in der Schule bist gib 6 ein)?

1. nicht-akademischer Abschluss
2. Bachelor
3. Master
4. Diplom/Magister/Stattsexamen
5. Promotion
6. Ich bin noch in der Schule

""")

response4 = input("Deine Antwort ist Nummer:")
if (response3 != "5"):
    response4 = "6"




#Question5
print("""
Welchen Schulabschluss haben deine Eltern (der höchste Abschluss)?

1. kein Abschluss
2. Hauptschulabschluss
3. mittlerer Abschluss
4. Fachhochschulreife
5. Algemeine Hochschulreife

""")

response5 = input("Deine Antwort ist Nummer:")


#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#ungerechtigkeit aufgrundlage von Abschluss Eltern

if (response5 =="1") or (response5 =="2") or (response5 =="3")   :
    if (response1 =="1"):
        plot_func3("Schulabschluss", "Hauptschulabschluss", df3, "männlich percentage")

        plot_func3("Schulabschluss", "Allgemeine Hochschulreife", df3, "männlich percentage")
    
#selbes Spiel für Frauen

if (response5 =="1") or (response5 =="2") or (response5 =="3")    :
    if (response1 =="2"):
        plot_func3("Schulabschluss", "Hauptschulabschluss", df3, "weiblich percentage")

        plot_func3("Schulabschluss", "Allgemeine Hochschulreife", df3, "weiblich percentage")

        
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!        


#ungerechtigkeit Hauptschulabschluss aufgrundlage von Migrationshintergrund

if (response3 == "1") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "Hauptschule_Abschluss", df8i)

    
if (response3 == "1") and (response1 == "2"):

    plot_func_select("Detaillierter Migrationshintergrund", "Hauptschule_Abschluss", df8m)

    plot_func_select("Detaillierter Migrationshintergrund", "Hauptschule_Abschluss", df8w)
    
    
#ungerechtigkeit Realschulabschluss aufgrundlage von Migrationshintergrund

if (response3 == "2") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "Realschule_Abschluss", df8i)

    
if (response3 == "2") and (response1 == "2"):

    plot_func_select("Detaillierter Migrationshintergrund", "Realschule_Abschluss", df8m)

    plot_func_select("Detaillierter Migrationshintergrund", "Realschule_Abschluss", df8w)
    

#ungerechtigkeit Fachhochschulreife aufgrundlage von Migrationshintergrund

if (response3 == "3") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "Fachhochschulreife", df8i)

    
if (response3 == "3") and (response1 == "2"):

    plot_func_select("Detaillierter Migrationshintergrund", "Fachhochschulreife", df8m)

    plot_func_select("Detaillierter Migrationshintergrund", "Fachhochschulreife", df8w)
    
    
#ungerechtigkeit Abitur aufgrundlage von Migrationshintergrund

if (response3 == "4") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "Abitur", df8i)

    
if (response3 == "4") and (response1 == "2"):

    plot_func_select("Detaillierter Migrationshintergrund", "Abitur", df8m)

    plot_func_select("Detaillierter Migrationshintergrund", "Abitur", df8w)

        
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!        

#ungerechtigkeit Habilitationen aufgrundlage von Migrationshintergrund

if (response4 == "5") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "Promotion", df9i)

    plot_func_select("Detaillierter Migrationshintergrund", "Promotion", df9m)

    plot_func_select("Detaillierter Migrationshintergrund", "Promotion", df9w)
    
if (response4 == "5") and (response1 == "2"):
    plot_func_select("Detaillierter Migrationshintergrund", "Promotion", df9m)

    plot_func_select("Detaillierter Migrationshintergrund", "Promotion", df9w)    
    
    
#ungerechtigkeit Master aufgrundlage von Migrationshintergrund

if (response4 == "3") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "Master", df9i)

    plot_func_select("Detaillierter Migrationshintergrund", "Master", df9m)

    plot_func_select("Detaillierter Migrationshintergrund", "Master", df9w)
    

if (response4 == "3") and (response1 == "2"):

    plot_func_select("Detaillierter Migrationshintergrund", "Master", df9m)

    plot_func_select("Detaillierter Migrationshintergrund", "Master", df9w)
    

#ungerechtigkeit Bachelor aufgrundlage von Migrationshintergrund

if (response4 == "2") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "Bachelor", df9i)

    plot_func_select("Detaillierter Migrationshintergrund", "Bachelor", df9m)

    plot_func_select("Detaillierter Migrationshintergrund", "Bachelor", df9w)
    

if (response4 == "2") and (response1 == "2"):

    plot_func_select("Detaillierter Migrationshintergrund", "Bachelor", df9m)

    plot_func_select("Detaillierter Migrationshintergrund", "Bachelor", df9w)
    
    
#ungerechtigkeit nicht akademischer Abschluss aufgrundlage von Migrationshintergrund

if (response4 == "1") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "nicht ak. Abschluss", df9i)

    plot_func_select("Detaillierter Migrationshintergrund", "nicht ak. Abschluss", df9m)

    plot_func_select("Detaillierter Migrationshintergrund", "nicht ak. Abschluss", df9w)
    

if (response4 == "1") and (response1 == "2"):

    plot_func_select("Detaillierter Migrationshintergrund", "nicht ak. Abschluss", df9m)

    plot_func_select("Detaillierter Migrationshintergrund", "nicht ak. Abschluss", df9w)
    
    
#ungerechtigkeit Magister/Diplom/Staatsexamen aufgrundlage von Migrationshintergrund

if (response4 == "4") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "Diplom/Magister/Staatsexamen", df9i)

    plot_func_select("Detaillierter Migrationshintergrund", "Diplom/Magister/Staatsexamen", df9m)

    plot_func_select("Detaillierter Migrationshintergrund", "Diplom/Magister/Staatsexamen", df9w)
    

if (response4 == "4") and (response1 == "2"):

    plot_func_select("Detaillierter Migrationshintergrund", "Diplom/Magister/Staatsexamen", df9m)

    plot_func_select("Detaillierter Migrationshintergrund", "Diplom/Magister/Staatsexamen", df9w)    
    



print("Danke fürs Mitmachen {}, Tschüss!".format(name))
# Out:
# Wie lautet dein Name?
#
# Bitte gib deinen Namen an: Arne
#
# Hey Arne, willkommen zu unserem Fragebogen. Dir werden im
# Folgenden insgesamt fünf Fragen gestellt anhand derer wir dir gerne
# ein paar Graphiken zur Bildungs- und (damit einhergehend) Chancenungleichheit
# in Deutschland aufzeigen wollen.
# Bitte beantworte die Fragen mit der davorstehenden Nummer
#
#
# Dein Geschlecht?
#
# 1. männlich
# 2. weiblich

# %%
#ungerechtigkeit aufgrundlage von Abschluss Eltern

if (response5 == "1") or (response5 == "2") or (response5 == "3")   :
    if (response1 =="1"):
        plot_func3("Schulabschluss", "Hauptschulabschluss", df3, "männlich percentage")

        plot_func3("Schulabschluss", "Allgemeine Hochschulreife", df3, "männlich percentage")
    
#selbes Spiel für Frauen

if (response5 == "1") or (response5 == "2") or (response5 == "3")   :
    if (response1 =="2"):
        plot_func3("Schulabschluss", "Hauptschulabschluss", df3, "weiblich percentage")

        plot_func3("Schulabschluss", "Allgemeine Hochschulreife", df3, "weiblich percentage")

# %%
#ungerechtigkeit Hauptschulabschluss aufgrundlage von Migrationshintergrund

if (response3 == "1") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "Hauptschule_Abschluss", df8i)

    
if (response3 == "1") and (response1 == "2"):

    plot_func_select("Detaillierter Migrationshintergrund", "Hauptschule_Abschluss", df8m)

    plot_func_select("Detaillierter Migrationshintergrund", "Hauptschule_Abschluss", df8w)
    
    
#ungerechtigkeit Realschulabschluss aufgrundlage von Migrationshintergrund

if (response3 == "2") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "Realschule_Abschluss", df8i)

    
if (response3 == "2") and (response1 == "2"):

    plot_func_select("Detaillierter Migrationshintergrund", "Realschule_Abschluss", df8m)

    plot_func_select("Detaillierter Migrationshintergrund", "Realschule_Abschluss", df8w)
    

#ungerechtigkeit Fachhochschulreife aufgrundlage von Migrationshintergrund

if (response3 == "3") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "Fachhochschulreife", df8i)

    
if (response3 == "3") and (response1 == "2"):

    plot_func_select("Detaillierter Migrationshintergrund", "Fachhochschulreife", df8m)

    plot_func_select("Detaillierter Migrationshintergrund", "Fachhochschulreife", df8w)
    
    
#ungerechtigkeit Abitur aufgrundlage von Migrationshintergrund

if (response3 == "4") and (response1 == "1"):
    plot_func_select("Detaillierter Migrationshintergrund", "Abitur", df8i)

    
if (response3 == "4") and (response1 == "2"):

    plot_func_select("Detaillierter Migrationshintergrund", "Abitur", df8m)

    plot_func_select("Detaillierter Migrationshintergrund", "Abitur", df8w)
